# %% [markdown]
# # №1 Вступ до машинного навчання. Лінійна регресія, логістична регресія, нелінійна регресія, нелінійна класифікація, багатокласова класифікація

# %% [markdown]
# Перед початком встановіть <code> tensorflow scikit-learn seaborn </code> у вашому віртуальному середовищі

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from IPython.display import Image
from sklearn.datasets import make_blobs, make_moons
from sklearn.preprocessing import StandardScaler

# Примусово вимикаємо GPU, щоб усунути помилку CUDA
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

sns.set_theme()

# %% [markdown]
# ## Лінійна регресія

# %%
def plot_linear_regression(x_points, y_points, y_pred=None, title=" ", x_label="", y_label=""):
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if y_pred is not None:
        plt.plot(x_points, y_pred, color="red", label="regression line")
    plt.scatter(x_points, y_points, color='blue')
    plt.show()

# %%
np.random.seed(42)

x_points = np.linspace(0, 100)
y_points =

plot_linear_regression(x_points, y_points, title="Дані")

# %% [markdown]
# Модель (рівняння прямої): $$y = \theta_1 x + \theta_2$$

# %%
def function(x, theta):

# %%
np.random.seed(5)

theta =

# %%
result = function(x_points, theta)

plot_linear_regression(x_points, y_points, result, title="Початкова ініціалізація")

# %% [markdown]
# Функція втрат середньоквадратична помилка (MSE):
# $$L = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
# або
# $$L = \frac{1}{n} \sum_{i=1}^{n} (y_i - (\theta_1 x_i + \theta_2))^2$$

# %%
L =
L

# %% [markdown]
# Обчислення градієнта.
# Щоб знайти, у який бік змінювати $\theta$, ми беремо частинні похідні від функції втрат за кожним параметром:
#
# $$\frac{\partial L}{\partial \theta_1} = -\frac{2}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i) \cdot x_i$$
#
# $$\frac{\partial L}{\partial \theta_2} = -\frac{2}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i) \cdot 1$$

# %%
derivative_theta1 =
derivative_theta2 =

gradient =
gradient

# %% [markdown]
# Оновлення параметрів за формулою градієнтного спуску:
# $$\theta_{new} = \theta_{old} - \alpha \cdot \nabla L$$

# %%
learning_rate = 0.0001

theta -= gradient * learning_rate
result = function(x_points, theta)

plot_linear_regression(x_points, y_points, result, title="Перший крок")

# %%
L_list = []
L_list.append(L)

learning_rate = 0.0001

for i in range(150):
    derivative_theta1 = -2/x_points.size*np.sum((y_points - result)*x_points)
    derivative_theta2 = -2/x_points.size*np.sum((y_points - result)*1)

    gradient = np.array([derivative_theta1, derivative_theta2])

    theta -= gradient * learning_rate
    result = function(x_points, theta)

    L = 1/x_points.size*np.sum((y_points-result)**2)
    L_list.append(L)

L

# %%
plot_linear_regression(x_points, y_points, result, "Кінцевий результат")

# %%
plt.plot(L_list, color='blue')
plt.title("Графік функції втрат")
plt.show()

# %%
L

# %% [markdown]
# ## Логістична регресія

# %%
def plot_logistic_regression(x0_0, x1_0, x0_1, x1_1, y_pred=None, x_points=None, title=""):
    plt.figure(figsize=(10, 6))

    plt.scatter(x0_0, x1_0, color='blue', marker='x', label='Class 0')
    plt.scatter(x0_1, x1_1, color='orange', marker='x', label='Class 1')

    if y_pred is not None and x_points is not None:
        plt.plot(x_points, y_pred, color="red", label="Prediction Line", linewidth=3)

    plt.title(title)
    plt.xlabel('x0')
    plt.ylabel('x1')
    plt.legend()
    plt.show()

# %%
np.random.seed(0)

n = 400
var = 1.1

x0_class0 = np.random.normal(1.5, var, n)
x1_class0 = np.random.normal(1.5, var, n)

x0_class1 = np.random.normal(4, var, n)
x1_class1 = np.random.normal(4, var, n)

plot_logistic_regression(x0_class0, x1_class0, x0_class1, x1_class1, title="Дані")

# %%
class_0 = np.vstack((x0_class0, x1_class0)).T
class_1 = np.vstack((x0_class1, x1_class1)).T

x = np.vstack((class_0, class_1))

y = np.hstack((np.zeros(n), np.ones(n)))

# %% [markdown]
# Модель прямої
# $$t = \theta_1 \cdot x_1 + \theta_2 \cdot x_2 + \theta_3$$
#
# Модель логістичної регресії
# $$\hat{y} = \sigma(t) = \frac{1}{1 + e^{-t}}$$

# %%
def sigmoid(t):

# %%
def func(x, theta):

# %%
t = np.linspace(-10, 10, 100)
plt.plot(t, sigmoid(t))

plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)
plt.hlines(0.5, -10, 10, linestyles='--', color='red')

plt.show()

# %%
np.random.seed(15)

theta_0 =
theta_1 =
theta_2 =

print(f'Початкові значення: {theta_0:0.4f}*x0 + {theta_1:0.4f}*x1 + {theta_2:0.4f}')

# %% [markdown]
# Функція втрат бінарна крос-ентропія (Binary Cross-Entropy Loss):
# $$L = -\frac{1}{n} \sum_{i=1}^{n} (y_i \cdot \ln(\hat{y}_i) + (1 - y_i) \cdot \ln(1 - \hat{y}_i))$$
#
# Обчислення градієнта:
# $$\frac{\partial L}{\partial \theta_0} = \frac{1}{n} \sum (\hat{y}_i - y_i) \cdot x_{i,0}$$
#
# $$\frac{\partial L}{\partial \theta_1} = \frac{1}{n} \sum (\hat{y}_i - y_i) \cdot x_{i,1}$$
#
# $$\frac{\partial L}{\partial \theta_2} = \frac{1}{n} \sum (\hat{y}_i - y_i) \cdot 1$$

# %%
def sigmoid(t):
    return 1 / (1 + np.exp(-t))

def func(x, theta):
    return sigmoid(x[:, 0] * theta[0] + x[:, 1] * theta[1] + theta[2])

def sigmoid_grad(t):


def loss_function(y, y_pred):


def gradient_calculation(x, y, y_pred):
    grad_theta_0 =
    grad_theta_1 =
    grad_theta_2 =

    return np.array([grad_theta_0, grad_theta_1, grad_theta_2])

# %%
np.random.seed(14)

lr = 0.1
theta =

y_pred =
cls_pred =
accuracy =
L =

loss = [L]
accs = [accuracy]

for _ in range(700):
    grad = gradient_calculation(x, y, y_pred)

    theta -= grad * lr

    y_pred =
    cls_pred =
    accuracy =
    L =

    loss.append(L)
    accs.append(accuracy)

# %%
Image(filename='training_with_epoch.gif')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

ax1.plot(loss)
ax1.set_title("Model Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss")

ax2.plot(accs)
ax2.set_title("Model Accuracy")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Accuracy")

plt.tight_layout()
plt.show()

# %%
# Поділимо дані по класах
df0 = pd.DataFrame({
    'x0':
    'x1':
    'y':
})

df1 = pd.DataFrame({
    'x0':
    'x1':
    'y':
})

df = pd.concat([df0, df1])
df.head(5)

# %%
df['y_pred'] =
df['cls_pred'] =

# Відобразимо датафрейм

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.scatterplot(data=df, x='x0', y='x1', hue='y', ax=axes[0])
axes[0].set_title("Оригінальні дані")

sns.scatterplot(data=df, x='x0', y='x1', hue='cls_pred', ax=axes[1])
axes[1].set_title("Результат мережі")

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='x0', y='x1', data=df, hue='y_pred')
plt.show()

# %% [markdown]
# ### Візуалізація процесу тренування (GIF анімація прокращення моделі в процесі тренування)

# %%
# import matplotlib.animation as animation
#
# np.random.seed(3532)
# lr = 1e-1
# theta = np.random.uniform(-1, 1, [3])
#
# fig, ax = plt.subplots(figsize=(8, 6))
# ax.scatter(class_0[:, 0], class_0[:, 1], color='blue', label='Class 0')
# ax.scatter(class_1[:, 0], class_1[:, 1], color='orange', label='Class 1')
#
# ax.set_xlim(-2, 8)
# ax.set_ylim(-2, 8)
# ax.set_title('Training Process Visualization')
# ax.set_xlabel('x0')
# ax.set_ylabel('x1')
# ax.legend()
#
# line, = ax.plot([], [], color='red', lw=2)
# epoch_text = ax.text(0.05, 0.95, '', transform=ax.transAxes, fontsize=14, verticalalignment='top')
#
# def update(frame):
#     global theta
#     y_pred = func(x, theta)
#     grad = gradient_calculation(x, y, y_pred)
#     theta -= grad * lr
#
#     x_vals = np.linspace(-2, 8, 100)
#     y_vals = -(theta[0] * x_vals + theta[2]) / theta[1]
#
#     epoch_text.set_text(f'Epoch: {frame + 1}')
#
#     line.set_data(x_vals, y_vals)
#     return line, epoch_text
#
# ani = animation.FuncAnimation(fig, update, frames=700, interval=50, blit=True)
#
# ani.save('training_with_epoch.gif', writer='imagemagick')
#
# plt.show()

# %% [markdown]
# ## Нелінійна регресія

# %%
np.random.seed(0)

x =
y =

df =
df

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(df, x='x', y='y', color='blue')  # Plot points as blue crosses
plt.title("Дані нелінійної регресії")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# Стандартизація даних
x_scaler =
y_scaler =

# Перетворюємо у стовпці
x_2d =
y_2d =

df['x_normed'] =
df['y_normed'] =

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(df, x='x_normed', y='y_normed', color='red')
plt.title("Non-linear regression data points")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
tf.random.set_seed(0)
np.random.seed(0)

model =

# Check model structure

# %%
# Compile model

# %%
# Train model
history =

# %%
plt.plot(history.history['loss'])

# %%
test_x = np.linspace(df.x.min(), df.x.max(), 100)

test_x_normed = x_scaler.transform(test_x.reshape(-1, 1))

pred_y_normed = model.predict(test_x_normed)
pred_y_denormed = y_scaler.inverse_transform(pred_y_normed)

plt.figure(figsize=(10, 6))
sns.scatterplot(df, x='x', y='y')
plt.plot(test_x, pred_y_denormed, color='r')
plt.title('Data Points')
plt.xlabel('X axis')
plt.ylabel('Y axis')

# %% [markdown]
# ## Нелінійна класифікація

# %%
X, y =

df =

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(df, x='x0', y='x1', hue='y', marker='s', palette='deep')

plt.title('Дані багатокласової класифікації')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x_normer = StandardScaler()
x =
y =

# %%
# Define model
model =

# %%
# Compile model

# %%
# Train model

# %%
y_pred =
cls_pred =

# %%
df['y_pred'] = y_pred
df['cls_pred'] = cls_pred
df

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.scatterplot(data=df, x='x0', y='x1', hue='y', marker='s', palette='deep', ax=axes[0])
axes[0].set_title("Оригінальні дані")

sns.scatterplot(data=df, x='x0', y='x1', hue='cls_pred', palette='deep', ax=axes[1])
axes[1].set_title("Результат мережі")

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='x0', y='x1', data=df, hue='y_pred')
plt.show()

# %%
# Створюємо сітку для відображення межі класифікації
x_min, x_max = df['x0'].min() - 0.5, df['x0'].max() + 0.5
y_min, y_max = df['x1'].min() - 0.5, df['x1'].max() + 0.5
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02), np.arange(y_min, y_max, 0.02))

x_grid = np.c_[xx.ravel(), yy.ravel()]
x_grid_scaled = x_normer.transform(x_grid)

Z = model.predict(x_grid_scaled)
Z = Z.reshape(xx.shape)

fig, ax = plt.subplots(figsize=(16, 6), ncols=2, sharex=True, sharey=True)

# Лівий графік: pcolormesh (ймовірності) + контур 0.5
ax[0].pcolormesh(xx, yy, Z, alpha=0.8, cmap='coolwarm', shading='auto')
# ax[0].contour(xx, yy, Z, levels=[0.5], colors='black', linewidths=2, linestyles='dashed')
sns.scatterplot(data=df, x='x0', y='x1', hue='y', palette='coolwarm', ax=ax[0])
ax[0].set_title("Ймовірності та межа (0.5)")

# Правий графік: результат класифікації (cls_pred)
ax[1].contourf(xx, yy, (Z > 0.5).astype(int), alpha=0.8, cmap='coolwarm')
sns.scatterplot(data=df, x='x0', y='x1', hue='cls_pred', palette='coolwarm', ax=ax[1])
ax[1].set_title("Результат класифікації")

plt.show()

# %% [markdown]
# ## Багатокласова класифікація

# %%
X, y =
df =

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(df, x='x0', y='x1', hue='y', marker='s', palette='deep')

plt.title('Дані багатокласової класифікації')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
df

# %%
x_normer =
x =

# %%
y =

# %%
# Define model
model =

# %%
# Compile model

# %%
# Train model

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(history.history['loss'])
axes[0].set_title("Model Loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")

axes[1].plot(history.history['accuracy'])
axes[1].set_title("Model Accuracy")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")

plt.tight_layout()
plt.show()

# %%
y_pred =
y_pred

# %%
pred_cls =
df['y_pred_cls'] = pred_cls

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.scatterplot(data=df, x='x0', y='x1', hue='y', marker='s', palette='deep', ax=axes[0])
axes[0].set_title("Оригінальні дані")

sns.scatterplot(data=df, x='x0', y='x1', hue='y_pred_cls', palette='deep', ax=axes[1])
axes[1].set_title("Результат мережі")

plt.tight_layout()
plt.show()
